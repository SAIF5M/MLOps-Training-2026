# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

df = pd.read_csv('artifacts/labeled_ml_table.csv')
print("Loaded labeled table shape:", df.shape)

train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42, stratify=df['is_late'])

val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df['is_late'])

print("Train set shape:", train_df.shape)
print("Validation set shape:", val_df.shape)
print("Test set shape:", test_df.shape)

os.makedirs('artifacts', exist_ok=True)
train_df.to_csv('artifacts/train.csv', index=False)
val_df.to_csv('artifacts/validation.csv', index=False)
test_df.to_csv('artifacts/test.csv', index=False)

print("Split artifacts (train, validation, test) saved successfully!")
# Out:
# Loaded labeled table shape: (99441, 19)
# Train set shape: (69608, 19)
# Validation set shape: (14916, 19)
# Test set shape: (14917, 19)
# Split artifacts (train, validation, test) saved successfully!
