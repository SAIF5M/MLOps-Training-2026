# %%
import pandas as pd

df = pd.read_csv('artifacts/merged_ml_table.csv')
print("Loaded merged table shape:", df.shape)

df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])
df['order_estimated_delivery_date'] = pd.to_datetime(df['order_estimated_delivery_date'])

df['is_late'] = (df['order_delivered_customer_date'] > df['order_estimated_delivery_date']).astype(int)

class_distribution = df['is_late'].value_counts()
print("Class distribution (0: On-time, 1: Late):\n", class_distribution)
# Out:
# Loaded merged table shape: (99441, 18)
# Class distribution (0: On-time, 1: Late):
#  is_late
# 0    91614
# 1     7827
# Name: count, dtype: int64

# %%
import os

os.makedirs('artifacts', exist_ok=True)
artifact_path = 'artifacts/labeled_ml_table.csv'
df.to_csv(artifact_path, index=False)

print(f"Labeled Artifact saved successfully at: {artifact_path}")
# Out:
# Labeled Artifact saved successfully at: artifacts/labeled_ml_table.csv
